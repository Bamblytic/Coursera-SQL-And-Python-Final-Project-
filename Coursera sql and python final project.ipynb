# %%
# !pip install pandas
# !pip install ipython-sql prettytable 
import pandas as pd
import prettytable

prettytable.DEFAULT = 'DEFAULT'

# %%
import sqlite3,csv 
con=sqlite3.connect('FinalDB.db')

# %%
# %load_ext sql
pd.set_option('display.max_columns', None)

# %% [markdown]
# #### Chicago Census Data

# %%
df=pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01')
df
# Out:
#     COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME  PERCENT_OF_HOUSING_CROWDED  \
# 0                     1.0         Rogers Park                         7.7
# 1                     2.0          West Ridge                         7.8
# 2                     3.0              Uptown                         3.8
# 3                     4.0      Lincoln Square                         3.4
# 4                     5.0        North Center                         0.3
# ..                    ...                 ...                         ...
# 73                   74.0     Mount Greenwood                         1.0
# 74                   75.0         Morgan Park                         0.8
# 75                   76.0              O'Hare                         3.6
# 76                   77.0           Edgewater                         4.1
# 77                    NaN             CHICAGO                         4.7
#
#     PERCENT_HOUSEHOLDS_BELOW_POVERTY  PERCENT_AGED_16__UNEMPLOYED  \
# ...

# %% [markdown]
# #### Chicago Public Schools

# %%
df2=pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01')
df2
# Out:
#      School_ID                                     NAME_OF_SCHOOL  \
# 0       610038                  Abraham Lincoln Elementary School
# 1       610281  Adam Clayton Powell Paideia Community Academy ...
# 2       610185                Adlai E Stevenson Elementary School
# 3       609993                    Agustin Lara Elementary Academy
# 4       610513                      Air Force Academy High School
# ..         ...                                                ...
# 561     610172                William T Sherman Elementary School
# 562     609844                 William W Carter Elementary School
# 563     610088                Wolfgang A Mozart Elementary School
# 564     609977               Woodlawn Community Elementary School
# 565     610392                 World Language Academy High School
#
#     Elementary, Middle, or High School         Street_Address     City State  \
# 0                                   ES        615 W Kemper Pl  Chicago    IL
# ...

# %% [markdown]
# #### Chicago Crime Data

# %%
df3=pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCrimeData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01')
df3
# Out:
#            ID CASE_NUMBER        DATE                     BLOCK  IUCR  \
# 0     3512276    HK587712  2004-08-28        047XX S KEDZIE AVE   890
# 1     3406613    HK456306  2004-06-26  009XX N CENTRAL PARK AVE   820
# 2     8002131    HT233595  2011-04-04        043XX S WABASH AVE   820
# 3     7903289    HT133522  2010-12-30      083XX S KINGSTON AVE   840
# 4    10402076    HZ138551  2016-02-02           033XX W 66TH ST   820
# ..        ...         ...         ...                       ...   ...
# 528  10453948    HZ192829  2016-03-01           028XX E 79TH ST  1055
# 529  10397129    HZ133234  2016-01-29       006XX W HARRISON ST  5114
# 530   3269495    HJ747227  2003-11-08           012XX W 81ST ST   510
# 531  10840565    JA143710  2017-02-06        009XX N KARLOV AVE  5073
# 532   1326195     G021609  2001-01-11       087XX S ESCANABA AV  9901
#
#                          PRIMARY_TYPE  \
# 0                               THEFT
# 1                               THEFT
# ...

# %% [markdown]
# #### Use these dataframes to load data on to the database FinalDB.db as required tables.

# %%
df.to_sql('Chicago Census Data',con,if_exists='replace',index=False,method='multi')
# Out:
# 78

# %%
df2.to_sql('Chicago Public Schools',con,if_exists='replace',index=False,method='multi')
# Out:
# 566

# %%
df3.to_sql('Chicago Crime Data',con,if_exists='replace',index=False,method='multi')
# Out:
# 533

# %% [markdown]
# #### Establish a connection between SQL magic module and the database `FinalDB.db`

# %%
# %sql sqlite:///FinalDB.db

# %% [markdown]
# ##### Find the total number of crimes recorded in the CRIME table.

# %%
# %sql select count(*)from 'Chicago Crime Data';
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(533,)]

# %% [markdown]
# ##### List community area names and numbers with per capita income less than 11000.

# %%
# %sql SELECT COMMUNITY_AREA_NAME, COMMUNITY_AREA_NUMBER FROM "Chicago Census Data" WHERE PER_CAPITA_INCOME < 11000;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('West Garfield Park', 26.0),
#  ('South Lawndale', 30.0),
#  ('Fuller Park', 37.0),
#  ('Riverdale', 54.0)]

# %% [markdown]
# #### List all case numbers for crimes involving minors?(children are not considered minors for the purposes of crime analysis)

# %%
# %sql select case_number from 'Chicago Crime Data' where description LIKE '%minor';
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('HL266884',), ('HK238408',)]

# %%
# %sql SELECT CASE_NUMBER FROM "Chicago Crime Data" WHERE DESCRIPTION LIKE '%MINOR%';
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('HL266884',), ('HK238408',)]

# %%
# %sql select* from  "Chicago Crime Data" WHERE  PRIMARY_TYPE = 'KIDNAPPING' AND DESCRIPTION LIKE '%child%';
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(5276766, 'HN144152', '2007-01-26', '050XX W VAN BUREN ST', '1792', 'KIDNAPPING', 'CHILD ABDUCTION/STRANGER', 'STREET', 0, 0, 1533, 15, 29.0, 25.0, '20', 1143050.0, 1897546.0, 2007, 41.87490841, -87.75024931, '(41.874908413, -87.750249307)')]

# %% [markdown]
# #### List the kind of crimes that were recorded at schools. (No repetitions)¶

# %%
# %sql select distinct (PRIMARY_TYPE)from "Chicago Crime Data" where LOCATION_DESCRIPTION LIKE '%school%';
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('BATTERY',),
#  ('CRIMINAL DAMAGE',),
#  ('NARCOTICS',),
#  ('ASSAULT',),
#  ('CRIMINAL TRESPASS',),
#  ('PUBLIC PEACE VIOLATION',)]

# %% [markdown]
# ##### List the type of schools along with the average safety score for each type.

# %%
# %sql select "Elementary, Middle, or High School", AVG(SAFETY_SCORE) AS 'Average_Safety_Score' from "Chicago Public Schools" group by "Elementary, Middle, or High School";
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('ES', 49.52038369304557), ('HS', 49.62352941176471), ('MS', 48.0)]

# %% [markdown]
# ##### List 5 community areas with highest % of households below poverty line

# %%
# %sql select COMMUNITY_AREA_NAME from "Chicago Census Data" ORDER BY PERCENT_HOUSEHOLDS_BELOW_POVERTY desc limit 5
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Riverdale',),
#  ('Fuller Park',),
#  ('Englewood',),
#  ('North Lawndale',),
#  ('East Garfield Park',)]

# %% [markdown]
# ##### Which community area is most crime prone? Display the coumminty area number only.

# %%
# %sql SELECT COMMUNITY_AREA_NUMBER FROM "Chicago Crime Data" GROUP BY COMMUNITY_AREA_NUMBER ORDER BY COUNT(*) DESC LIMIT 1;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(25.0,)]

# %% [markdown]
# ##### Use a sub-query to find the name of the community area with highest hardship index

# %%
# %sql select COMMUNITY_AREA_NAME FROM "Chicago Census Data"  WHERE HARDSHIP_INDEX = (SELECT MAX(HARDSHIP_INDEX)  FROM "Chicago Census Data");
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Riverdale',)]

# %% [markdown]
# ##### Use a sub-query to determine the Community Area Name with most number of crimes?

# %%
# %sql SELECT COMMUNITY_AREA_NAME FROM "Chicago Census Data" WHERE COMMUNITY_AREA_NUMBER = (SELECT COMMUNITY_AREA_NUMBER FROM "Chicago Crime Data" GROUP BY COMMUNITY_AREA_NUMBER ORDER BY COUNT(*) DESC LIMIT 1);
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Austin',)]
